# %%
pip install google-generativeai python-dotenv
# Out:
# Requirement already satisfied: google-generativeai in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (0.7.2)
# Requirement already satisfied: python-dotenv in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (1.2.1)
# Collecting google-ai-generativelanguage==0.6.6 (from google-generativeai)
#   Using cached google_ai_generativelanguage-0.6.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: google-api-core in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (2.43.0)
# Requirement already satisfied: protobuf in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (4.25.8)
# Requirement already satisfied: pydantic in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (2.12.5)
# Requirement already satisfied: tqdm in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-ai-generativelanguage==0.6.6->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.6->google-generativeai) (1.62.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from pydantic->google-generativeai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Using cached google_ai_generativelanguage-0.6.6-py3-none-any.whl (718 kB)
# Installing collected packages: google-ai-generativelanguage
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.9.0
#     Uninstalling google-ai-generativelanguage-0.9.0:
#       Successfully uninstalled google-ai-generativelanguage-0.9.0
# Successfully installed google-ai-generativelanguage-0.6.6
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 3.2.0 requires google-ai-generativelanguage<1.0.0,>=0.9.0, but you have google-ai-generativelanguage 0.6.6 which is incompatible.

# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Configure the API key
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# Initialize the model
model = genai.GenerativeModel('gemini-2.0-flash')

# Make your first API call
response = model.generate_content(
    "what is generative AI?",
    generation_config=genai.GenerationConfig(
        temperature=0.7,
    )
)

# Print the response
print(response.text)
# Out:
# Generative AI refers to a class of artificial intelligence models that can generate new content, such as text, images, audio, video, and even code. Unlike traditional AI models that are primarily designed to analyze and interpret data, generative AI models are trained to create novel and original outputs that resemble the data they were trained on.
#
# Here's a breakdown of key aspects of generative AI:
#
# **Core Functionality:**
#
# *   **Generates New Content:** The primary function is to create something new, not just analyze or classify existing data. This "newness" can range from slightly modified versions of existing data to entirely original creations.
# *   **Learns from Data:** These models are trained on vast datasets of existing content.  They learn the underlying patterns, structures, and styles within that data.
# *   **Uses Probabilistic Models:** Generative AI often uses probabilistic models. It predicts the probability of the next element (e.g., word, pixel, note) in a sequence, based on the preceding elements and the patterns it learned during training.
# *   **Variety of Output:**  Generative AI can produce a wide range of outputs, including:
#     *   **Text:** Articles, poems, scripts, code, summaries, translations, chatbots.
#     *   **Images:** Realistic photos, paintings, illustrations, art styles, image editing.
#     *   **Audio:** Music, speech, sound effects, voice cloning.
#     *   **Video:** Short clips, animations, video editing, realistic simulations.
#     *   **3D Models:** Objects, scenes, characters.
#     *   **Code:** Software code in various programming languages.
#
# **Key Techniques and Architectures:**
#
# Several different AI architectures are used for generative AI, each with its strengths and weaknesses:
#
# *   **Generative Adversarial Networks (GANs):** GANs consist of two neural networks: a generator that creates new data and a discriminator that tries to distinguish between real and generated data.  The generator is trained to fool the discriminator, leading to increasingly realistic outputs.  GANs are widely used for image and video generation.
# *   **Variational Autoencoders (VAEs):** VAEs learn a compressed, latent representation of the input data.  This latent space can then be sampled from to generate new data points that resemble the original data.
# *   **Transformers:** Transformers are a powerful neural network architecture initially developed for natural language processing.  They excel at capturing long-range dependencies in data and are used in models like GPT (Generative Pre-trained Transformer) for text generation and DALL-E for image generation.
# *   **Diffusion Models:** Diffusion models work by gradually adding noise to the training data until it becomes pure noise. Then, the model learns to reverse this process, starting from noise and gradually removing it to generate new, realistic data.  These models are particularly effective for high-quality image generation.
#
# **Examples of Generative AI in Action:**
#
# *   **ChatGPT (OpenAI):** A large language model that can generate human-like text for various purposes, including writing articles, answering questions, and creating conversational chatbots.
# *   **DALL-E 2 and Midjourney:** AI image generators that can create realistic images from text descriptions.
# *   **Stable Diffusion:**  Another popular image generation model, known for its open-source nature and customization options.
# *   **GitHub Copilot:** An AI-powered code completion tool that suggests code snippets and even entire functions based on the context of the code being written.
# *   **RunwayML:** A platform with various generative AI tools for video editing, image manipulation, and other creative tasks.
#
# **Potential Applications:**
#
# Generative AI has a vast range of potential applications across various industries:
#
# *   **Creative Arts:**  Generating art, music, writing, and other forms of creative content.
# *   **Entertainment:** Creating realistic special effects, developing new video games, and personalizing entertainment experiences.
# *   **Marketing:**  Generating advertising copy, creating product images, and personalizing marketing campaigns.
# *   **Education:**  Creating personalized learning materials and generating interactive simulations.
# *   **Healthcare:**  Developing new drugs, analyzing medical images, and creating personalized treatment plans.
# *   **Manufacturing:**  Designing new products, optimizing manufacturing processes, and generating realistic simulations for training.
# *   **Software Development:** Automating code generation, improving software quality, and assisting developers in debugging.
#
# **Challenges and Considerations:**
#
# While generative AI holds immense promise, it also presents several challenges and ethical considerations:
#
# *   **Bias:** Generative AI models can inherit biases from the data they are trained on, leading to outputs that are unfair or discriminatory.
# *   **Misinformation:** Generative AI can be used to create fake news, deepfakes, and other forms of misinformation, which can have serious consequences.
# *   **Copyright and Intellectual Property:** The use of copyrighted material in training data raises questions about copyright infringement and the ownership of generated content.
# *   **Job Displacement:**  Generative AI has the potential to automate tasks currently performed by humans, leading to job displacement in certain industries.
# *   **Ethical Use:**  It's crucial to develop guidelines and regulations for the responsible and ethical use of generative AI to mitigate potential risks and ensure that it is used for good.
# *   **Hallucination:**  Generative AI models, especially large language models, can sometimes "hallucinate" and generate information that is factually incorrect or nonsensical.  This can be a significant problem in applications where accuracy is critical.
# *   **Resource Intensive:** Training and running generative AI models can be computationally expensive, requiring significant resources and energy.
#
# In summary, generative AI is a rapidly evolving field with the potential to revolutionize many aspects of our lives. By understanding its capabilities, limitations, and ethical implications, we can harness its power for good while mitigating potential risks.

# %%
# Creative writing
response = model.generate_content(
    "Write a story about...",
    generation_config=genai.GenerationConfig(
        temperature=0.9,
        max_output_tokens=500,
        top_p=0.9
    )
)

# Factual Q&A
response = model.generate_content(
    "What is the capital of...",
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        max_output_tokens=50,
        top_p=0.1
    )
)

# Code generation
response = model.generate_content(
    "Write a Python function...",
    generation_config=genai.GenerationConfig(
        temperature=0.3,
        max_output_tokens=30,
    )
)

# %%
# Print the response
print(response.text)
# Out:
# Okay, I'm ready.  Please tell me what you want the Python function to do.  For example, you could tell me:
