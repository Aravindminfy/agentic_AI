# %%
pip install langchain-community pypdf
# Out:
# Requirement already satisfied: langchain-community in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (0.2.4)
# Collecting pypdf
#   Downloading pypdf-6.4.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (0.2.0)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain-community)
#   Using cached langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community)
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (0.2.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.0)
# Requirement already satisfied: anyio in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.11.0)
# Requirement already satisfied: certifi in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\minfy.desktop-3e50d5n\documents\agenticai\learn_basic\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.1)
# Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Downloading pypdf-6.4.0-py3-none-any.whl (329 kB)
# Installing collected packages: pypdf, langsmith, langchain-core
#
#    ---------------------------------------- 0/3 [pypdf]
#    ---------------------------------------- 0/3 [pypdf]
#   Attempting uninstall: langsmith
#    ---------------------------------------- 0/3 [pypdf]
#     Found existing installation: langsmith 0.4.49
#    ---------------------------------------- 0/3 [pypdf]
#     Uninstalling langsmith-0.4.49:
#    ---------------------------------------- 0/3 [pypdf]
#    ------------- -------------------------- 1/3 [langsmith]
#       Successfully uninstalled langsmith-0.4.49
#    ------------- -------------------------- 1/3 [langsmith]
#    ------------- -------------------------- 1/3 [langsmith]
#    ------------- -------------------------- 1/3 [langsmith]
#    ------------- -------------------------- 1/3 [langsmith]
#   Attempting uninstall: langchain-core
#    ------------- -------------------------- 1/3 [langsmith]
#     Found existing installation: langchain-core 1.1.0
#    ------------- -------------------------- 1/3 [langsmith]
#    -------------------------- ------------- 2/3 [langchain-core]
#     Uninstalling langchain-core-1.1.0:
#    -------------------------- ------------- 2/3 [langchain-core]
#       Successfully uninstalled langchain-core-1.1.0
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    -------------------------- ------------- 2/3 [langchain-core]
#    ---------------------------------------- 3/3 [langchain-core]
#
# Successfully installed langchain-core-0.2.43 langsmith-0.1.147 pypdf-6.4.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-anthropic 1.2.0 requires langchain-core<2.0.0,>=1.1.0, but you have langchain-core 0.2.43 which is incompatible.
# langchain-classic 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.2.43 which is incompatible.
# langchain-classic 1.0.0 requires langchain-text-splitters<2.0.0,>=1.0.0, but you have langchain-text-splitters 0.2.4 which is incompatible.
# langchain-google-genai 3.2.0 requires langchain-core<2.0.0,>=1.1.0, but you have langchain-core 0.2.43 which is incompatible.
# langchain-openai 1.1.0 requires langchain-core<2.0.0,>=1.1.0, but you have langchain-core 0.2.43 which is incompatible.
# langgraph-prebuilt 1.0.5 requires langchain-core>=1.0.0, but you have langchain-core 0.2.43 which is incompatible.

# %%
import getpass
import os

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_API_KEY"] = getpass.getpass()

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = "nke-10k-2023.pdf"
loader = PyPDFLoader(file_path)

docs = loader.load()

print(len(docs))
# Out:
# 107

# %%
print(f"{docs[0].page_content[:200]}\n")
print(docs[0].metadata)
# Out:
# Table of Contents
# UNITED STATES
# SECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# FORM 10-K
# (Mark One)
# ☑  ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(D) OF THE SECURITIES EXCHANGE ACT OF 1934
# F
#
# {'source': 'nke-10k-2023.pdf', 'page': 0}

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, add_start_index=True
)
all_splits = text_splitter.split_documents(docs)

print(len(all_splits))
# Out:
# 516

# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key for Google Gemini: ")

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
# Out:
# c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\_python_version_support.py:266: FutureWarning: You are using a Python version (3.10.6) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
vector_1 = embeddings.embed_query(all_splits[0].page_content)
vector_2 = embeddings.embed_query(all_splits[1].page_content)

assert len(vector_1) == len(vector_2)
print(f"Generated vectors of length {len(vector_1)}\n")
print(vector_1[:10])
# Out:
# Generated vectors of length 3072
#
# [0.0031224784906953573, -0.010247742757201195, 0.002103641629219055, -0.02493170090019703, -0.010411160066723824, -0.005388996098190546, 0.013277474790811539, -0.021302081644535065, -0.012513947673141956, 0.009936078451573849]

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
ids = vector_store.add_documents(documents=all_splits)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\langchain_google_genai\embeddings.py:306, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     305 try:
# --> 306     result = self.client.batch_embed_contents(
#     307         BatchEmbedContentsRequest(requests=requests, model=self.model)
#     308     )
#     309 except Exception as e:
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:1438, in GenerativeServiceClient.batch_embed_contents(self, request, model, requests, retry, timeout, metadata)
#    1437 # Send the request.
# -> 1438 response = rpc(
#    1439     request,
#    1440     retry=retry,
#    1441     timeout=timeout,
#    1442     metadata=metadata,
#    1443 )
#    1445 # Done; return the response.
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\retry\retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\retry\retry_unary.py:156, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154 except Exception as exc:
#     155     # defer to shared logic for handling errors
# --> 156     next_sleep = _retry_error_helper(
#     157         exc,
#     158         deadline,
#     159         sleep_iter,
#     160         error_list,
#     161         predicate,
#     162         on_error,
#     163         exception_factory,
#     164         timeout,
#     165     )
#     166     # if exception not raised, sleep before next attempt
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\retry\retry_base.py:214, in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     209     final_exc, source_exc = exc_factory_fn(
#     210         error_list,
#     211         RetryFailureReason.NON_RETRYABLE_ERROR,
#     212         original_timeout,
#     213     )
# --> 214     raise final_exc from source_exc
#     215 if on_error_fn is not None:
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\retry\retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     146 try:
# --> 147     result = target()
#     148     if inspect.isawaitable(result):
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\google\api_core\grpc_helpers.py:77, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76 except grpc.RpcError as exc:
# ---> 77     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ids = vector_store.add_documents(documents=all_splits)
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\langchain_core\vectorstores\in_memory.py:194, in InMemoryVectorStore.add_documents(self, documents, ids, **kwargs)
#     186 @override
#     187 def add_documents(
#     188     self,
#    (...)
#     191     **kwargs: Any,
#     192 ) -> list[str]:
#     193     texts = [doc.page_content for doc in documents]
# --> 194     vectors = self.embedding.embed_documents(texts)
#     196     if ids and len(ids) != len(texts):
#     197         msg = (
#     198             f"ids must be the same length as texts. "
#     199             f"Got {len(ids)} ids and {len(texts)} texts."
#     200         )
#
# File c:\Users\Minfy.DESKTOP-3E50D5N\Documents\agenticAI\learn_basic\venv\lib\site-packages\langchain_google_genai\embeddings.py:311, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     309     except Exception as e:
#     310         msg = f"Error embedding content: {e}"
# --> 311         raise GoogleGenerativeAIError(msg) from e
#     312     embeddings.extend([list(e.values) for e in result.embeddings])
#     313 return embeddings
#
# GoogleGenerativeAIError: Error embedding content: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 0 [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/embed_content_free_tier_requests"
#   quota_id: "EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier"
# }
# ]

# %%
results = vector_store.similarity_search(
    "How many distribution centers does Nike have in the US?"
)

print(results[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 5
#       1 results = vector_store.similarity_search(
#       2     "How many distribution centers does Nike have in the US?"
#       3 )
# ----> 5 print(results[0])
#
# IndexError: list index out of range
